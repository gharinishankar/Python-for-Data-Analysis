# %%
import sys
import numpy as np

# %%
A = np.array([
    ['a', 'b', 'c'],
    ['d', 'e', 'f'],
    ['g', 'h', 'i']
])

print(A[:, :2])
# Out:
# [['a' 'b']
#  ['d' 'e']
#  ['g' 'h']]

# %%
a = np.array([5,3,2,1,1])
print(a)
# Out:
# [5 3 2 1 1]

# %%
b = np.array(([3,4,2],[2,2,2]))
print(b)
# Out:
# [[3 4 2]
#  [2 2 2]]

# %%
print(b[:2,:3])
# Out:
# [[3 4 2]
#  [2 2 2]]

# %%
a = np.arange(5)
a + 20
# Out:
# array([20, 21, 22, 23, 24])

# %%
print(b.shape)
# Out:
# (2, 3)

# %%
print(b.size)
# Out:
# 6

# %%
print(b.dtype)
# Out:
# int64

# %%
print(b[0,1])
# Out:
# 4

# %%
print(b[0,0])
# Out:
# 3

# %%
print(b[1,0])
# Out:
# 2

# %%
print(b[b>1])
# Out:
# [3 4 2 2 2 2]

# %%
print(b+1)
# Out:
# [[4 5 3]
#  [3 3 3]]

# %%
print(b.sum(a
